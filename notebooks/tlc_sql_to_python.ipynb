# %% [markdown]
# # Converting TLC SQL Queries to Python DataFrames
# - This is a copy of our class lecture on 6/7 but changed to match my capstone needs

# %% [markdown]
# In this notebook, you'll see how to connect to a Postgres database using the sqlalchemy library.
#
# For this notebook, you'll need both the `sqlalchemy` and `psycopg2` libraries installed.

# %%
from sqlalchemy import create_engine

# %% [markdown]
# First, we need to create a connection string. The format is
#
#  ```<dialect(+driver)>://<username>:<password>@<hostname>:<port>/<database>```
#
# To connect to a database, you can use the following connection string.

# %%
database_name = 'ag_aid'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %% [markdown]
# Now, we need to create an engine and use it to connect.

# %%
engine = create_engine(connection_string)

# %% [markdown]
# Now, we can create our query and pass it into the `.query()` method.

# %%
query = '''
WITH cit AS (
SELECT
    (RIGHT(begin_date,2)::int) AS year,
    job_title,
    workers_req,
    SUM(workers_req::FLOAT) OVER() as wr_total,
    employer_state,
    worksite_state
FROM main
WHERE job_title ILIKE '%%citrus%%'
    AND (RIGHT(begin_date,2)::int) >= 10
GROUP BY year, job_title, employer_state, workers_req, worksite_state
ORDER BY year)

SELECT year,
    job_title,
    workers_req,
    wr_total,
    SUM(workers_req::FLOAT) OVER(PARTITION BY year) AS wr_total_year,
    employer_state,
    worksite_state
FROM cit
''' # Everything between these 3 single quotes is on one line

result = engine.execute(query)

# %% [markdown]
# You can then fetch the results as tuples using either `fetchone` or `fetchall`:

# %%
result.fetchone()
# Out:
# (10, 'CITRUS HAND HARVESTER', '117', 57652.0, 1045.0, 'FL', 'FL')

# %%
result.fetchall()
# Out:
# [(10, 'CITRUS HAND HARVESTER', '121', 57652.0, 1045.0, 'FL', 'FL'),
#  (10, 'CITRUS HAND HARVESTER', '156', 57652.0, 1045.0, 'FL', 'FL'),
#  (10, 'CITRUS HAND HARVESTER', '16', 57652.0, 1045.0, 'FL', 'FL'),
#  (10, 'CITRUS HAND HARVESTER', '47', 57652.0, 1045.0, 'FL', 'FL'),
#  (10, 'CITRUS HAND HARVESTER', '64', 57652.0, 1045.0, 'FL', 'FL'),
#  (10, 'CITRUS HAND HARVESTER', '97', 57652.0, 1045.0, 'FL', 'FL'),
#  (10, 'CITRUS HAND HARVESTING', '200', 57652.0, 1045.0, 'FL', 'FL'),
#  (10, 'CITRUS HAND HAVESTER', '210', 57652.0, 1045.0, 'MS', 'FL'),
#  (10, 'CITRUS TRUCK DRIVER, HAULER', '17', 57652.0, 1045.0, 'FL', 'FL'),
#  (11, 'CITRUS FRUIT HARVESTING', '24', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '106', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '137', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '151', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '16', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '24', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '297', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '328', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '34', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '46', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '48', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '79', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '90', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '95', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '98', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS HAND HARVESTER', '204', 57652.0, 2115.0, 'MS', 'FL'),
#  (11, 'CITRUS HAND HARVESTOR', '325', 57652.0, 2115.0, 'FL', 'FL'),
#  (11, 'CITRUS TRUCK DRIVER, HAULER', '13', 57652.0, 2115.0, 'FL', 'FL'),
#  (12, 'CITRUS AND WATERMELON HAND HARVESTER', '81', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS FRUIT HARVESTING', '25', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND-HARVESTER', '18', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND-HARVESTER', '30', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '102', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '135', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '15', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '158', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '16', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '199', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '204', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '325', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '332', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '334', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '35', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '54', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '60', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '72', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '96', 57652.0, 2344.0, 'FL', 'FL'),
#  (12, 'CITRUS HAND HARVESTER', '53', 57652.0, 2344.0, 'MS', 'FL'),
#  (13, 'Avocado and Citrus Harvester', '24', 57652.0, 6499.0, 'CA', 'CA'),
#  (13, 'Citrus and Watermelon Hand Harvester', '80', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus and Watermelon Hand Harvester', '99', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '0', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '10', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '100', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '110', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '114', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '121', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '129', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '130', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '133', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '14', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '149', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '154', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '171', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '173', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '189', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '190', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '193', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '20', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '202', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '21', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '22', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '225', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '23', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '24', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '25', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '257', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '266', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '270', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '276', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '279', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '28', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '30', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '390', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '44', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '46', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '48', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '49', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '54', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '55', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '60', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '61', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '72', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '76', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '90', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '96', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvester', '10', 57652.0, 6499.0, 'MS', 'FL'),
#  (13, 'Citrus Hand Harvester', '172', 57652.0, 6499.0, 'MS', 'FL'),
#  (13, 'Citrus Hand Harvester', '20', 57652.0, 6499.0, 'MS', 'FL'),
#  (13, 'Citrus Hand Harvester', '48', 57652.0, 6499.0, 'MS', 'FL'),
#  (13, 'Citrus Hand Harvester', '50', 57652.0, 6499.0, 'MS', 'FL'),
#  (13, 'Citrus Hand Harvester', '70', 57652.0, 6499.0, 'MS', 'FL'),
#  (13, 'CITRUS HAND HARVESTER', '400', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvesters', '25', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvesters', '38', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvesting', '40', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Hand Harvesting', '49', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'CITRUS HAND HARVESTING', '44', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'CITRUS HAND HARVESTING', '70', 57652.0, 6499.0, 'FL', 'FL'),
#  (13, 'Citrus Picker', '71', 57652.0, 6499.0, 'FL', 'FL'),
#  (14, 'Avocado and Citrus Harvester', '13', 57652.0, 7414.0, 'CA', 'CA'),
#  (14, 'Citrus Hand-Harvesters', '49', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvest', '20', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'CITRUS HAND HARVEST', '110', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '0', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '100', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '102', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '104', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '110', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '111', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '113', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '131', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '14', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '15', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '186', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '20', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '200', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '201', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '21', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '222', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '225', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '239', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '25', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '257', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '26', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '276', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '30', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '300', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '360', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '40', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '42', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '431', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '44', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '45', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '48', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '50', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '52', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '56', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '577', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '60', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '63', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '65', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '71', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '74', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '75', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '90', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '99', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvester', '0', 57652.0, 7414.0, 'MS', 'FL'),
#  (14, 'Citrus Hand Harvester', '10', 57652.0, 7414.0, 'MS', 'FL'),
#  (14, 'Citrus Hand Harvester', '110', 57652.0, 7414.0, 'MS', 'FL'),
#  (14, 'Citrus Hand Harvester', '200', 57652.0, 7414.0, 'MS', 'FL'),
#  (14, 'Citrus Hand Harvester', '25', 57652.0, 7414.0, 'MS', 'FL'),
#  (14, 'Citrus Hand Harvester', '258', 57652.0, 7414.0, 'MS', 'FL'),
#  (14, 'Citrus Hand Harvester', '35', 57652.0, 7414.0, 'MS', 'FL'),
#  (14, 'Citrus Hand Harvester', '50', 57652.0, 7414.0, 'MS', 'FL'),
#  (14, 'Citrus Hand Harvester', '55', 57652.0, 7414.0, 'MS', 'FL'),
#  (14, 'Citrus Hand Harvester', '66', 57652.0, 7414.0, 'MS', 'FL'),
#  (14, 'CITRUS HAND HARVESTER', '40', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'CITRUS HAND HARVESTER', '49', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvesters', '14', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvesters', '15', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvesters', '18', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvesters', '27', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvesters', '28', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvesters', '41', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Hand Harvesting', '226', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'CITRUS HAND HARVESTING', '23', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'CITRUS HAND HARVESTING', '24', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'CITRUS HAND HARVESTING', '25', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'CITRUS HAND HARVESTING', '41', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'CITRUS HAND HARVESTING', '70', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus Picker', '71', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Citrus/Blueberry Hand Harvester', '199', 57652.0, 7414.0, 'FL', 'FL'),
#  (14, 'Farm Labor/ Citrus Harvester', '132', 57652.0, 7414.0, 'FL', 'FL'),
#  (15, 'Avocado and Citrus Harvester', '18', 57652.0, 7227.0, 'CA', 'CA'),
#  (15, 'CITRUS & MELON HAND-HARVESTERS', '49', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand-Harvesters', '20', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVEST', '0', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVEST', '20', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '108', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '110', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '112', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '120', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '15', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '160', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '180', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '199', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '20', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '21', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '213', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '218', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '224', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '225', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '24', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '26', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '269', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '276', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '28', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '291', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '30', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '300', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '36', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '360', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '40', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '42', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '431', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '47', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '48', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '49', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '50', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '56', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '60', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '64', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '65', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '74', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '84', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '90', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvester', '10', 57652.0, 7227.0, 'MS', 'FL'),
#  (15, 'Citrus Hand Harvester', '100', 57652.0, 7227.0, 'MS', 'FL'),
#  (15, 'Citrus Hand Harvester', '170', 57652.0, 7227.0, 'MS', 'FL'),
#  (15, 'Citrus Hand Harvester', '172', 57652.0, 7227.0, 'MS', 'FL'),
#  (15, 'Citrus Hand Harvester', '200', 57652.0, 7227.0, 'MS', 'FL'),
#  (15, 'Citrus Hand Harvester', '25', 57652.0, 7227.0, 'MS', 'FL'),
#  (15, 'Citrus Hand Harvester', '26', 57652.0, 7227.0, 'MS', 'FL'),
#  (15, 'Citrus Hand Harvester', '45', 57652.0, 7227.0, 'MS', 'FL'),
#  (15, 'CITRUS HAND HARVESTER', '25', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTER', '40', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTER', '51', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTER', '63', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTER', '632', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTER', '71', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvesters', '16', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvesters', '26', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Hand Harvesting', '49', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTING', '0', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTING', '12', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTING', '18', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTING', '20', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTING', '24', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTING', '30', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTING', '49', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTING', '70', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'CITRUS HAND HARVESTING', '72', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Citrus Technologist', '1', 57652.0, 7227.0, 'CA', 'CA'),
#  (15, 'CITRUS,MELON,BERRY,TOMATO PICKERS', '239', 57652.0, 7227.0, 'FL', 'FL'),
#  (15, 'Farmworkers, Citrus/Crop', '99', 57652.0, 7227.0, 'FL', 'FL'),
#  (16, 'Avocado and Citrus Harvester', '24', 57652.0, 6397.0, 'CA', 'CA'),
#  (16, 'Citrus Hand-Harvesters', '20', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '0', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '110', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '112', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '118', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '120', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '122', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '15', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '165', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '170', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '177', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '195', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '20', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '21', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '228', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '232', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '25', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '257', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '26', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '276', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '28', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '280', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '30', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '340', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '37', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '40', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '41', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '42', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '431', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '45', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '48', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '49', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '50', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '55', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '56', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '58', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '60', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '70', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '85', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '87', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '98', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvester', '12', 57652.0, 6397.0, 'MS', 'FL'),
#  (16, 'Citrus Hand Harvester', '122', 57652.0, 6397.0, 'MS', 'FL'),
#  (16, 'Citrus Hand Harvester', '145', 57652.0, 6397.0, 'MS', 'FL'),
#  (16, 'Citrus Hand Harvester', '230', 57652.0, 6397.0, 'MS', 'FL'),
#  (16, 'Citrus Hand Harvester', '25', 57652.0, 6397.0, 'MS', 'FL'),
#  (16, 'Citrus Hand Harvester', '45', 57652.0, 6397.0, 'MS', 'FL'),
#  (16, 'Citrus Hand Harvester', '48', 57652.0, 6397.0, 'MS', 'FL'),
#  (16, 'CITRUS HAND HARVESTER', '200', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS HAND HARVESTER', '24', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS HAND HARVESTER', '283', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS HAND HARVESTER', '33', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS HAND HARVESTER', '85', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvesters', '15', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvesters', '24', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Hand Harvesters', '38', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS HAND HARVESTING', '40', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Harvester', '130', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'Citrus Harvesters', '142', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS HARVESTING', '0', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS HARVESTING', '17', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS HARVESTING', '24', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS HARVESTING', '82', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS, PEACH, AND BLUEBERRY HARVESTING', '30', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS, WATERMELON, AND TOMATO HARVESTING', '20', 57652.0, 6397.0, 'FL', 'FL'),
#  (16, 'CITRUS,BERRY,TOMATO PICKERS', '120', 57652.0, 6397.0, 'FL', 'FL'),
#  (17, 'Avocado and Citrus Harvester', '26', 57652.0, 7734.0, 'CA', 'CA'),
#  (17, 'Citrus (Lemon) Harvest, Grape Pruning', '52', 57652.0, 7734.0, 'CA', 'CA'),
#  (17, 'CITRUS AND BLUEBERRY HAND HARVESTING', '75', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '0', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '103', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '105', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '108', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '110', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '112', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '16', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '165', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '17', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '170', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '195', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '20', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '218', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '238', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '24', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '257', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '260', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '270', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '30', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '320', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '37', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '386', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '41', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '42', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '44', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '47', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '48', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '500', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '60', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '61', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '70', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '74', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '77', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvester', '85', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'CITRUS HAND HARVESTER', '169', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'CITRUS HAND HARVESTER', '265', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'CITRUS HAND HARVESTER', '316', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'CITRUS HAND HARVESTER', '60', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus hand harvesters', '20', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Hand Harvesting', '180', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Harvester', '200', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Harvester', '397', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Harvester', '60', 57652.0, 7734.0, 'FL', 'AR'),
#  (17, 'Citrus Harvester', '60', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Harvester', '60', 57652.0, 7734.0, 'FL', 'MS'),
#  (17, 'Citrus Harvesters', '17', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Harvesting', '25', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'CITRUS HARVESTING', '115', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'CITRUS HARVESTING', '28', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Citrus Pickers', '30', 57652.0, 7734.0, 'AZ', 'AZ'),
#  (17, 'Citrus Worker', '120', 57652.0, 7734.0, 'CA', 'CA'),
#  (17, 'Citrus Worker; Forklift Driver; Tree Pruning & Gen', '125', 57652.0, 7734.0, 'CA', 'CA'),
#  (17, 'CITRUS, PEACH, AND BLUEBERRY HARVESTING', '18', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'CITRUS, WATERMELON, BLUEBERRY, AND STRAWBERRY', '30', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'CITRUS,MELON,BERRY PICKERS', '285', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'CITRUS,MELON,BERRY,VEG PICKERS', '354', 57652.0, 7734.0, 'FL', 'FL'),
#  (17, 'Field Workers (Citrus)', '300', 57652.0, 7734.0, 'AZ', 'AZ'),
#  (17, 'hand harvest citrus', '37', 57652.0, 7734.0, 'FL', 'FL'),
#  (18, 'Avocado and Citrus Harvester, pruner', '0', 57652.0, 7910.0, 'CA', 'CA'),
#  (18, 'CITRUS AND HAND HARVESTER', '63', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Farmworker', '90', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand-Harvesters', '40', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '108', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '143', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '150', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '155', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '16', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '18', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '190', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '197', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '20', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '24', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '255', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '30', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '317', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '332', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '40', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '400', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '42', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '426', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '45', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '47', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '48', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '56', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '60', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '74', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '80', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvester', '84', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'CITRUS HAND HARVESTER', '127', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'citrus hand harvesters', '25', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '112', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '124', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '127', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '372', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '40', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '44', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '47', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '500', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '62', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '99', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Hand Harvesters', '146', 57652.0, 7910.0, 'MS', 'FL'),
#  (18, 'Citrus Hand Harvesters', '147', 57652.0, 7910.0, 'MS', 'FL'),
#  (18, 'Citrus Hand Harvesters', '94', 57652.0, 7910.0, 'MS', 'FL'),
#  (18, 'CITRUS HAND HAVESTER', '268', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'CITRUS HARVESTER', '18', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'CITRUS HARVESTER', '651', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Harvesting', '40', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Harvesting', '80', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'CITRUS HARVESTING', '22', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'CITRUS HARVESTING', '27', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus Worker', '123', 57652.0, 7910.0, 'CA', 'CA'),
#  (18, 'Citrus Worker', '40', 57652.0, 7910.0, 'CA', 'CA'),
#  (18, 'CITRUS,MELON,BERRY,NURSERY', '704', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Citrus,Watermelon, Blueberry, and', '35', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Farmworkers & Laborers (Citrus)', '40', 57652.0, 7910.0, 'CA', 'CA'),
#  (18, 'Farmworkers & Laborers, Citrus', '60', 57652.0, 7910.0, 'AZ', 'AZ'),
#  (18, 'Farmworkers Citrus', '25', 57652.0, 7910.0, 'FL', 'FL'),
#  (18, 'Farmworkers Laborers (Citrus)', '30', 57652.0, 7910.0, 'CA', 'CA'),
#  (18, 'Field Workers: Citrus, Peaches, Dates', '75', 57652.0, 7910.0, 'AZ', 'CA'),
#  (18, 'STRAWBERRY AND CITRUS HARVESTER', '56', 57652.0, 7910.0, 'FL', 'FL'),
#  (19, 'Avocado, Strawberry, Citrus Harvester, Pruner', '0', 57652.0, 6549.0, 'CA', 'CA'),
#  (19, 'CITRUS AND BLUEBERRY HARVESTER', '116', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'CITRUS AND BLUEBERRY HARVESTER', '16', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand-Harvesters', '59', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '125', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '158', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '194', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '195', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '197', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '21', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '218', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '23', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '241', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '38', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '40', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '42', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '44', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '45', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '46', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '48', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '60', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', '8', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvester', None, 57652.0, 6549.0, 'PA', 'PA'),
#  (19, 'Citrus Hand Harvesters', '109', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '11', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '110', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '159', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '29', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '336', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '35', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '39', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '41', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '500', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '55', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '74', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '75', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '80', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '91', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Hand Harvesters', '99', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'CITRUS HARVESTER', '240', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'CITRUS HARVESTER', '350', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'CITRUS HARVESTER', '50', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'CITRUS HARVESTER', '90', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Harvesters', '24', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Harvesters', '46', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Harvesting', '30', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'CITRUS HARVESTING', '18', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'CITRUS HARVESTING', '19', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'CITRUS HARVESTING', '22', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'CITRUS HARVESTING', '32', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Haulers', None, 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'CITRUS HAULERS', '20', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Citrus Worker, Forklift Driver, Tree Pruning', '45', 57652.0, 6549.0, 'CA', 'CA'),
#  (19, 'Citrus Worker; Forklift Driver, Tree Pruner', '40', 57652.0, 6549.0, 'CA', 'CA'),
#  (19, 'Citrus Worker; Tree Pruning; Forklift Driver', '100', 57652.0, 6549.0, 'CA', 'CA'),
#  (19, 'Citrus Worker; Tree Pruning; Forklift Driver; General Labor', '130', 57652.0, 6549.0, 'CA', 'CA'),
#  (19, 'Citrus Worker; Tree Pruning; Forklift Driver; Truck Driver; ', '133', 57652.0, 6549.0, 'CA', 'CA'),
#  (19, 'CITRUS,MELON,BERRY,NURSERY', '524', 57652.0, 6549.0, 'FL', 'FL'),
#  (19, 'Farm Laborers: Citrus Harvest', '40', 57652.0, 6549.0, 'CA', 'CA'),
#  (19, 'Field Worker: Citrus (Lemons, Oranges, Minneolas)', '130', 57652.0, 6549.0, 'AZ', 'AZ'),
#  (19, 'Field Worker: Citrus (Lemons, Oranges, Minneolas)', '66', 57652.0, 6549.0, 'AZ', 'AZ'),
#  (19, 'Field Worker: Citrus (Lemons, Oranges, Minneolas)', '134', 57652.0, 6549.0, 'CA', 'CA'),
#  (19, 'Field Worker: Citrus (Lemons, Oranges, Minneolas)', '46', 57652.0, 6549.0, 'CA', 'CA'),
#  (19, 'Field Worker: Citrus (Lemons, Oranges, Minneolas)', '68', 57652.0, 6549.0, 'CA', 'CA'),
#  (19, 'Field Workers (Citrus, Olives and Dates) Tractor', '275', 57652.0, 6549.0, 'AZ', 'AZ'),
#  (19, 'Field Workers: Citrus, Peaches, Dates', '100', 57652.0, 6549.0, 'AZ', 'CA'),
#  (20, ' (Citrus, Olives and Dates) Tractor, Forklift Drivers', '350', 57652.0, 2418.0, 'CA', 'AZ'),
#  (20, 'Avocado and Citrus Harvester/pruner', '7', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Avocado and Citrus Harvester/pruner', None, 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Citrus & Hemp Harvesting and Field Work', '25', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus hand Harvester', '42', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvester', '14', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvester', '16', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvester ', '28', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvesters', '100', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvesters', '110', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvesters', '134', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvesters', '14', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvesters', '16', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvesters', '165', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvesters', '33', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvesters', '36', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvesters', '65', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Hand Harvesters', '99', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus hand harvesters ', None, 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Harvesters', '158', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Harvesters', '45', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Harvesting and Grove Maintenance', None, 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Haulers', '4', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Produce Packer ', '24', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus Worker', '50', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Citrus Worker, Forklift Driver, CalVan Driver, Tree Pruning ', '45', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Citrus/Hauling', '3', 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Citrus/Hauling', None, 57652.0, 2418.0, 'FL', 'FL'),
#  (20, 'Farm Laborers: Citrus Harvest ', '40', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Field Worker  (Citrus Harvesting)', '20', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Field Worker  Citrus Harvesting', '15', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Field Workers (Citrus, Peaches and Dates) Fruit Wash Line', '148', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Field Workers (Citrus, Peaches, and Dates)', '50', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Field Workers: Citrus (Lemons, Oranges, Minneolas) Pickers', '130', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Field Workers: Citrus (Lemons, Oranges, Minneolas) Pickers', '147', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Field Workers: Citrus (Lemons, Oranges, Minneolas) Pickers', '159', 57652.0, 2418.0, 'CA', 'AZ'),
#  (20, 'General Farm Workers: Citrus and Table Grapes', '98', 57652.0, 2418.0, 'CA', 'CA'),
#  (20, 'Grape and Citrus', '28', 57652.0, 2418.0, 'CA', 'CA')]

# %% [markdown]
# On the other hand, sqlalchemy plays nicely with pandas.

# %%
import pandas as pd

# %%
# people = pd.DataFrame(data, 'user')

# %%
cit = pd.read_sql(query, con = engine)
cit.head()
# Out:
#    year              job_title workers_req  wr_total  wr_total_year  \
# 0    10  CITRUS HAND HARVESTER         117   57652.0         1045.0
# 1    10  CITRUS HAND HARVESTER         121   57652.0         1045.0
# 2    10  CITRUS HAND HARVESTER         156   57652.0         1045.0
# 3    10  CITRUS HAND HARVESTER          16   57652.0         1045.0
# 4    10  CITRUS HAND HARVESTER          47   57652.0         1045.0
#
#   employer_state worksite_state
# 0             FL             FL
# 1             FL             FL
# 2             FL             FL
# 3             FL             FL
# 4             FL             FL

# %% [markdown]
# For much more information about SQLAlchemy and to see a more “Pythonic” way to execute queries, see Introduction to Databases in Python: https://www.datacamp.com/courses/introduction-to-relational-databases-in-python
